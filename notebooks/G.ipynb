# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

csv_path = "../data/so.csv"
df = pd.DataFrame.from_csv(csv_path)

# %%
df[df['gender'].isin(['Male', 'Female'])]
# Out:
#       collector         country        un_subregion       so_region age_range  \
# 1888   Facebook     Afghanistan       Southern Asia    Central Asia     20-24
# 4637   Facebook     Afghanistan       Southern Asia    Central Asia     30-34
# 21378  Facebook     Afghanistan       Southern Asia    Central Asia       NaN
# 51301  Facebook     Afghanistan       Southern Asia    Central Asia     25-29
# 24487  Facebook         Albania     Southern Europe  Eastern Europe     20-24
# 49685  Facebook         Albania     Southern Europe  Eastern Europe     20-24
# 50525  Facebook         Albania     Southern Europe  Eastern Europe     25-29
# 50541  Facebook         Albania     Southern Europe  Eastern Europe     25-29
# 51884  Facebook         Albania     Southern Europe  Eastern Europe     20-24
# 2303   Facebook         Algeria     Northern Africa          Africa     40-49
# 2375   Facebook         Algeria     Northern Africa          Africa     25-29
# ...

# %%
df.gender = df.gender == 'Male'
df.corr()
# Out:
#                      age_midpoint    gender  experience_midpoint  \
# age_midpoint             1.000000  0.013732             0.678134
# gender                   0.013732  1.000000             0.074505
# experience_midpoint      0.678134  0.074505             1.000000
# salary_midpoint          0.472576  0.022581             0.494521
# big_mac_index            0.209626  0.002964             0.230981
# programming_ability      0.287924  0.102043             0.467293
#
#                      salary_midpoint  big_mac_index  programming_ability
# age_midpoint                0.472576       0.209626             0.287924
# gender                      0.022581       0.002964             0.102043
# experience_midpoint         0.494521       0.230981             0.467293
# salary_midpoint             1.000000       0.505519             0.328932
# big_mac_index               0.505519       1.000000             0.124460
# programming_ability         0.328932       0.124460             1.000000

# %%
df.star_wars_vs_star_trek.value_counts()
# Out:
# Star Wars               22410
# Star Trek                8148
# Star Wars; Star Trek     3840
# Name: star_wars_vs_star_trek, dtype: int64

# %%
df.desktop_os.value_counts()
# Out:
# Mac OS X         12150
# Windows 7        10439
# Windows 10        9661
# Ubuntu            5713
# Windows 8         3906
# Other Linux       2050
# Debian             894
# Mint               794
# Fedora             625
# Windows XP         170
# Windows Vista       49
# Name: desktop_os, dtype: int64

# %%
sorted(df.columns)
# Out:
# ['age_midpoint',
#  'age_range',
#  'agree_adblocker',
#  'agree_alcohol',
#  'agree_diversity',
#  'agree_legacy',
#  'agree_loveboss',
#  'agree_mars',
#  'agree_nightcode',
#  'agree_notice',
#  'agree_problemsolving',
#  'agree_tech',
#  'aliens',
#  'big_mac_index',
#  'collector',
#  'commit_frequency',
#  'company_size_range',
#  'country',
#  'desktop_os',
#  'dev_environment',
#  'developer_challenges',
#  'dogs_vs_cats',
#  'education',
#  'employment_status',
#  'experience_midpoint',
#  'experience_range',
#  'gender',
#  'hobby',
#  'how_to_improve_interview_process',
#  'important_buildexisting',
#  'important_buildnew',
#  'important_companymission',
#  'important_control',
#  'important_newtech',
#  'important_ownoffice',
#  'important_promotion',
#  'important_sameend',
#  'important_variety',
#  'important_wfh',
#  'industry',
#  'interview_likelihood',
#  'job_discovery',
#  'job_satisfaction',
#  'job_search_annoyance',
#  'new_job_value',
#  'occupation',
# ...

# %%
df.experience_range.value_counts().plot(kind='bar')

# %%
data = df[['age_midpoint', 'un_subregion', 'experience_range', 'desktop_os', 'gender', 'agree_diversity']]
data['is_javascript'] = df['tech_do'].str.contains('JavaScript')
# Out:
# D:\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
data.groupby('desktop_os').is_javascript.value_counts().plot(kind='bar')

# %%
print(len(data))
print(len(data.dropna()))
# Out:
# 56030
# 40882
